# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline

# %%
# CARREGAR ARQUIVOS DE DADOS  - CSV - EXCELL
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Alberto Pinalli/Documents/GitHub/SGBD/set/vgsales.csv')

# %%
df.head(20) 
# head(data, 6)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.isnull().any()
# Out:
# Rank            False
# Name            False
# Platform        False
# Year             True
# Genre           False
# Publisher        True
# NA_Sales        False
# EU_Sales        False
# JP_Sales        False
# Other_Sales     False
# Global_Sales    False
# dtype: bool

# %%
df['Genre'].value_counts().plot( kind='bar',figsize=(10,5))

# %%
sns.barplot(x = df.Global_Sales, y = df.Genre)

# %%
df['NA_Sales'].plot(figsize=(10,5))

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
l=LabelEncoder()

# %%
df['Genre']=l.fit_transform(df['Genre'])

# %%
# df['Publisher']=l.fit_transform(df['Publisher'])

# %%
cor=df.corr()
cor
# Out:
#                   Rank      Year     Genre  NA_Sales  EU_Sales  JP_Sales  \
# Rank          1.000000  0.178814 -0.053018 -0.401362 -0.379123 -0.267785
# Year          0.178814  1.000000 -0.124994 -0.091402  0.006014 -0.169316
# Genre        -0.053018 -0.124994  1.000000  0.017435  0.016481  0.030085
# NA_Sales     -0.401362 -0.091402  0.017435  1.000000  0.767727  0.449787
# EU_Sales     -0.379123  0.006014  0.016481  0.767727  1.000000  0.435584
# JP_Sales     -0.267785 -0.169316  0.030085  0.449787  0.435584  1.000000
# Other_Sales  -0.332986  0.041058  0.009731  0.634737  0.726385  0.290186
# Global_Sales -0.427407 -0.074735  0.021671  0.941047  0.902836  0.611816
#
#               Other_Sales  Global_Sales
# Rank            -0.332986     -0.427407
# Year             0.041058     -0.074735
# Genre            0.009731      0.021671
# NA_Sales         0.634737      0.941047
# EU_Sales         0.726385      0.902836
# JP_Sales         0.290186      0.611816
# ...

# %%
sns.heatmap(cor)

# %%
x = df.iloc[:,[4,5,6,7,8,9]]
y = df.iloc[:,[10]]

# %%
y
# Out:
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 1 columns]

# %%
x
# Out:
#        Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         10    Nintendo     41.49     29.02      3.77         8.46
# 1          4    Nintendo     29.08      3.58      6.81         0.77
# 2          6    Nintendo     15.85     12.88      3.79         3.31
# 3         10    Nintendo     15.75     11.01      3.28         2.96
# 4          7    Nintendo     11.27      8.89     10.22         1.00
# ...      ...         ...       ...       ...       ...          ...
# 16593      4       Kemco      0.01      0.00      0.00         0.00
# 16594      8  Infogrames      0.01      0.00      0.00         0.00
# 16595      6  Activision      0.00      0.00      0.00         0.00
# 16596      5    7G//AMES      0.00      0.01      0.00         0.00
# 16597      4     Wanadoo      0.01      0.00      0.00         0.00
#
# [16598 rows x 6 columns]

# %%
sc=StandardScaler()
